# %% [markdown]
# ## Extra plotting with ggplot2
#
# ggplot2 is an great package for making pretty plots.
#
# This notebook will only descripe ggplot2 very shortly, as there are other excellent resources descibing the details:
# * [The Cookbook - Comprehensive collection with detailed information](http://www.cookbook-r.com/Graphs/)
# * [The R graph gallery - All the visualizations you can think of (ggplot2 and more)](https://www.r-graph-gallery.com/)
# * 4 hour ggplot2 webinar - [Part 1](https://www.youtube.com/watch?v=h29g21z0a68) and [Part 2](https://www.youtube.com/watch?v=0m4yywqNPVY)
#
# **Cheatsheet - 2-page pdf with a summary of ggplot2:**

# %% [markdown]
# <object data="https://rstudio.com/wp-content/uploads/2016/11/ggplot2-cheatsheet-2.1.pdf" type="application/pdf" width="1000px" height="1520px">
#     <embed src="https://rstudio.com/wp-content/uploads/2016/11/ggplot2-cheatsheet-2.1.pdf">
#         <p>This browser does not support PDFs. Please download the PDF to view it: <a href="https://rstudio.com/wp-content/uploads/2016/11/ggplot2-cheatsheet-2.1.pdf">Download PDF</a>.</p>
#     </embed>
# </object>

# %%
# Load ggplot2
library(ggplot2)

# %%
# Data
data(mtcars)

# %% [markdown]
# ## ggplot2 components
# The backbone is created with the ggplot function, where we input our data.frame:

# %%
ggplot(mtcars)
# Out:
# plot without title

# %% [markdown]
# ### Aesthetics
# Usually we would also add the aesthetics (aes), which tells which variables should be on the x-axes, on the y-axis, and if any variables should be used to indicate color, shape, or linetype.

# %%
ggplot(mtcars, aes(x = hp, y = disp, color = gear))
# Out:
# plot without title

# %% [markdown]
# ### Geometrics
# This however does not draw the plot. We need to add geometrics (geom), which tells ggplot2 how to plot the data:

# %%
ggplot(mtcars, aes(x = hp, y = disp, color = gear)) +
    geom_point()
# Out:
# plot without title

# %% [markdown]
# ### Themes
# We can then add a theme:

# %%
ggplot(mtcars, aes(x = hp, y = disp, color = gear)) +
    geom_point() +
    theme_bw()
# Out:
# plot without title

# %% [markdown]
# ### Scales
# We can add scales:

# %%
ggplot(mtcars, aes(x = hp, y = disp, color = gear)) +
    geom_point() +
    theme_bw() +
    scale_x_continuous(name="HP", breaks=seq(0,350,50))
# Out:
# plot without title

# %% [markdown]
# ### Labels
# We can add labels:

# %%
ggplot(mtcars, aes(x = hp, y = disp, color = gear)) +
    geom_point() +
    theme_bw() +
    scale_x_continuous(name="HP", breaks=seq(0,350,50)) +
    ylab("New label") +
    ggtitle("My title")
# Out:
# plot without title

# %% [markdown]
# ### Facetting
# We can facet the plot, by splitting it by a variable:

# %%
ggplot(mtcars, aes(x = hp, y = disp, color = gear)) +
    geom_point() +
    theme_bw() +
    scale_x_continuous(name="HP", breaks=seq(0,350,50)) +
    ylab("New label") +
    ggtitle("My title") +
    facet_grid(.~cyl)
# Out:
# plot without title

# %% [markdown]
# ### Regressions
# We can add a linear regression:

# %%
ggplot(mtcars, aes(x = hp, y = disp, color = gear)) +
    geom_point() +
    theme_bw() +
    scale_x_continuous(name="HP", breaks=seq(0,350,50)) +
    ylab("New label") +
    ggtitle("My title") +
    facet_grid(.~cyl) +
    stat_smooth(method = "lm")
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title
